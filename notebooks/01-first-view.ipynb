# %%
# %load_ext watermark
# %watermark -v -n -m -p numpy,sklearn,pandas
# Out:
# Mon Jan 28 2019
#
# CPython 3.6.5
# IPython 5.3.0
#
# numpy 1.16.0
# sklearn 0.19.1
# pandas 0.24.0
#
# compiler   : GCC 4.8.2 20140120 (Red Hat 4.8.2-15)
# system     : Linux
# release    : 4.15.0-43-generic
# machine    : x86_64
# processor  : x86_64
# CPU cores  : 8
# interpreter: 64bit

# %%
import os
import pandas as pd

# %%
PROJ_ROOT = os.path.abspath(os.path.join(os.pardir))
print(PROJ_ROOT)
# %cd ..
# Out:
# /media/DATA/elo_merchant
# /media/DATA/elo_merchant

# %%
train = pd.read_csv('./data/raw/train.csv')
train.shape
# Out:
# (201917, 6)

# %%
train.head()
# Out:
#   first_active_month          card_id  feature_1  feature_2  feature_3  \
# 0            2017-06  C_ID_92a2005557          5          2          1
# 1            2017-01  C_ID_3d0044924f          4          1          0
# 2            2016-08  C_ID_d639edf6cd          2          2          0
# 3            2017-09  C_ID_186d6a6901          4          3          0
# 4            2017-11  C_ID_cdbd2c0db2          1          3          0
#
#      target
# 0 -0.820283
# 1  0.392913
# 2  0.688056
# 3  0.142495
# 4 -0.159749

# %%
test = pd.read_csv('./data/raw/test.csv')
test.shape
# Out:
# (123623, 5)

# %%
test.head()
# Out:
#   first_active_month          card_id  feature_1  feature_2  feature_3
# 0            2017-04  C_ID_0ab67a22ab          3          3          1
# 1            2017-01  C_ID_130fd0cbdd          2          3          0
# 2            2017-08  C_ID_b709037bc5          5          1          1
# 3            2017-12  C_ID_d27d835a9f          2          1          0
# 4            2015-12  C_ID_2b5e3df5c2          5          1          1

# %%
merchants = pd.read_csv('./data/raw/merchants.csv')
merchants.shape
# Out:
# (334696, 22)

# %%
merchants.head()
# Out:
#        merchant_id  merchant_group_id  merchant_category_id  subsector_id  \
# 0  M_ID_838061e48c               8353                   792             9
# 1  M_ID_9339d880ad               3184                   840            20
# 2  M_ID_e726bbae1e                447                   690             1
# 3  M_ID_a70e9c5f81               5026                   792             9
# 4  M_ID_64456c37ce               2228                   222            21
#
#    numerical_1  numerical_2 category_1 most_recent_sales_range  \
# 0    -0.057471    -0.057471          N                       E
# 1    -0.057471    -0.057471          N                       E
# 2    -0.057471    -0.057471          N                       E
# 3    -0.057471    -0.057471          Y                       E
# 4    -0.057471    -0.057471          Y                       E
#
#   most_recent_purchases_range  avg_sales_lag3  ...  avg_sales_lag6  \
# 0                           E           -0.40  ...           -2.25
# ...

# %%
def print_value_counts(df):
    for column in df.columns:
        print(df[column].value_counts())

# %%
print_value_counts(merchants)
# Out:
# M_ID_42697d5d44    4
# M_ID_ebbdb42da6    4
# M_ID_30340088f2    4
# M_ID_c2b9ac2ea4    4
# M_ID_992a180b15    4
# M_ID_d123532c72    4
# M_ID_6464db3b45    4
# M_ID_bd49e37dda    4
# M_ID_dbbf07ebf0    4
# M_ID_ef233cff26    4
# M_ID_1802942aaf    4
# M_ID_6c144405a0    2
# M_ID_28c2aace87    2
# M_ID_654509ddbc    2
# M_ID_508ecbdcde    2
# M_ID_c0b712e11a    2
# M_ID_1ceca881f0    2
# M_ID_49b779bc8a    2
# M_ID_a8767b29ef    2
# M_ID_0a00fa9e8a    2
# M_ID_a55beb9d9a    2
# M_ID_ae9fe1605a    2
# M_ID_0c4018d3a0    2
# M_ID_645a6af169    2
# M_ID_57e97f6546    2
# M_ID_7251df88ad    2
# M_ID_26d4fadb60    2
# M_ID_7483dde87d    2
# M_ID_d2b5d4418d    2
# M_ID_b794b9d9e8    2
#                   ..
# M_ID_f9c4feb7dd    1
# M_ID_1a56d3a71f    1
# M_ID_bde591d544    1
# M_ID_7daeb49e2e    1
# M_ID_c24ce748e3    1
# M_ID_3e3f8d62a5    1
# M_ID_0dc87b2369    1
# M_ID_53bb0a0f6e    1
# M_ID_d79b9078f0    1
# M_ID_9bee1ae2e0    1
# M_ID_a41a47a13a    1
# M_ID_ce5966536d    1
# ...

# %%
merchants.isna().sum()
# Out:
# merchant_id                        0
# merchant_group_id                  0
# merchant_category_id               0
# subsector_id                       0
# numerical_1                        0
# numerical_2                        0
# category_1                         0
# most_recent_sales_range            0
# most_recent_purchases_range        0
# avg_sales_lag3                    13
# avg_purchases_lag3                 0
# active_months_lag3                 0
# avg_sales_lag6                    13
# avg_purchases_lag6                 0
# active_months_lag6                 0
# avg_sales_lag12                   13
# avg_purchases_lag12                0
# active_months_lag12                0
# category_4                         0
# city_id                            0
# state_id                           0
# category_2                     11887
# dtype: int64

# %%
new_merchant_transactions = pd.read_csv('./data/raw/new_merchant_transactions.csv')
new_merchant_transactions.shape
# Out:
# (1963031, 14)

# %%
new_merchant_transactions.head()
# Out:
#   authorized_flag          card_id  city_id category_1  installments  \
# 0               Y  C_ID_415bb3a509      107          N             1
# 1               Y  C_ID_415bb3a509      140          N             1
# 2               Y  C_ID_415bb3a509      330          N             1
# 3               Y  C_ID_415bb3a509       -1          Y             1
# 4               Y  C_ID_ef55cf8d4b       -1          Y             1
#
#   category_3  merchant_category_id      merchant_id  month_lag  \
# 0          B                   307  M_ID_b0c793002c          1
# 1          B                   307  M_ID_88920c89e8          1
# 2          B                   507  M_ID_ad5237ef6b          2
# 3          B                   661  M_ID_9e84cda3b1          1
# 4          B                   166  M_ID_3c86fa3831          1
#
#    purchase_amount        purchase_date  category_2  state_id  subsector_id
# 0        -0.557574  2018-03-11 14:57:36         1.0         9            19
# ...

# %%
print_value_counts(new_merchant_transactions)
# Out:
# Y    1963031
# Name: authorized_flag, dtype: int64
# C_ID_b7ebee6539    109
# C_ID_c729288535    106
# C_ID_8946508722    104
# C_ID_0e4f6af077    104
# C_ID_6cef1dba4b    100
# C_ID_4e8e856f1a     99
# C_ID_8e0c15d39b     95
# C_ID_4a0143e1a7     92
# C_ID_a9b2895f68     90
# C_ID_5da6f7704e     88
# C_ID_35b76f6fbe     87
# C_ID_d694ba3656     87
# C_ID_373694d1e5     86
# C_ID_349e4e9230     85
# C_ID_5ed8d518bb     84
# C_ID_463a87ae3c     82
# C_ID_b4c0e5d5ce     82
# C_ID_f250bd6aa0     82
# C_ID_4f21bba899     82
# C_ID_238c55d25e     80
# C_ID_8a0fd1ed32     80
# C_ID_a2ab74da8d     79
# C_ID_5f9dc1333c     79
# C_ID_3f3fde1e4d     78
# C_ID_a890d98a64     78
# C_ID_2fed5089f7     78
# C_ID_154e48f40a     77
# C_ID_ee54bf0f8d     76
# C_ID_6a475da44d     74
# C_ID_1e16af1aa1     73
#                   ...
# C_ID_579b9de85b      1
# C_ID_a1793953a2      1
# C_ID_00df5d97d3      1
# C_ID_2fa52141dc      1
# C_ID_bb2311b84e      1
# C_ID_2ce3824da5      1
# ...

# %%
new_merchant_transactions.isna().sum()
# Out:
# authorized_flag              0
# card_id                      0
# city_id                      0
# category_1                   0
# installments                 0
# category_3               55922
# merchant_category_id         0
# merchant_id              26216
# month_lag                    0
# purchase_amount              0
# purchase_date                0
# category_2              111745
# state_id                     0
# subsector_id                 0
# dtype: int64

# %%
historical_transactions = pd.read_csv('./data/raw/historical_transactions.csv')
historical_transactions.shape
# Out:
# (29112361, 14)

# %%
historical_transactions.head()
# Out:
#   authorized_flag          card_id  city_id category_1  installments  \
# 0               Y  C_ID_4e6213e9bc       88          N             0
# 1               Y  C_ID_4e6213e9bc       88          N             0
# 2               Y  C_ID_4e6213e9bc       88          N             0
# 3               Y  C_ID_4e6213e9bc       88          N             0
# 4               Y  C_ID_4e6213e9bc       88          N             0
#
#   category_3  merchant_category_id      merchant_id  month_lag  \
# 0          A                    80  M_ID_e020e9b302         -8
# 1          A                   367  M_ID_86ec983688         -7
# 2          A                    80  M_ID_979ed661fc         -6
# 3          A                   560  M_ID_e6d5ae8ea6         -5
# 4          A                    80  M_ID_e020e9b302        -11
#
#    purchase_amount        purchase_date  category_2  state_id  subsector_id
# 0        -0.703331  2017-06-25 15:33:07         1.0        16            37
# ...

# %%
print_value_counts(historical_transactions)
# Out:
# Y    26595452
# N     2516909
# Name: authorized_flag, dtype: int64
# C_ID_3d3dfdc692    5582
# C_ID_0cd2ce025c    2912
# C_ID_cc3d4cd4e3    2143
# C_ID_5ccc07beb9    2066
# C_ID_5ea401d358    1786
# C_ID_9f81506906    1665
# C_ID_6ae9f40da5    1665
# C_ID_272aa0597a    1647
# C_ID_9f63809b99    1634
# C_ID_80c1c711c9    1593
# C_ID_2524b5234d    1550
# C_ID_f352d1be7e    1546
# C_ID_0b84a29e2e    1517
# C_ID_f085d75a85    1491
# C_ID_66197df71f    1478
# C_ID_7dca81e0f1    1462
# C_ID_eda5dc78fe    1457
# C_ID_f028f3b41c    1450
# C_ID_89d1b0c84e    1441
# C_ID_62698b6025    1432
# C_ID_fef34cc0a0    1428
# C_ID_003e56029c    1414
# C_ID_4d3a26f711    1401
# C_ID_47fc988e9b    1390
# C_ID_94cf87a008    1389
# C_ID_d15ffb9f61    1370
# C_ID_d89f18e507    1350
# C_ID_60368fbef5    1347
# C_ID_3b16fb38f1    1344
# C_ID_1678a64139    1323
#                    ...
# C_ID_6762df0a84       2
# C_ID_30d4ea0992       2
# C_ID_6e5a557872       2
# C_ID_1f8a2b8d3e       2
# ...

# %%
historical_transactions.isna().sum()
# Out:
# authorized_flag               0
# card_id                       0
# city_id                       0
# category_1                    0
# installments                  0
# category_3               178159
# merchant_category_id          0
# merchant_id              138481
# month_lag                     0
# purchase_amount               0
# purchase_date                 0
# category_2              2652864
# state_id                      0
# subsector_id                  0
# dtype: int64
